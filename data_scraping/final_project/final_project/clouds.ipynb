# %%
from wordcloud import WordCloud
import json
import matplotlib.pyplot as plt

# %%
actors = [
    ('Dwayne Johnson', 'https://www.imdb.com/name/nm0425005/'),
    ('Chris Hemsworth', 'https://www.imdb.com/name/nm1165110/'),
    ('Robert Downey Jr.', 'https://www.imdb.com/name/nm0000375/'),
    ('Akshay Kumar', 'https://www.imdb.com/name/nm0474774/'),
    ('Jackie Chan', 'https://www.imdb.com/name/nm0000329/'),
    ('Bradley Cooper', 'https://www.imdb.com/name/nm0177896/'),
    ('Adam Sandler', 'https://www.imdb.com/name/nm0001191/'),
    ('Scarlett Johansson', 'https://www.imdb.com/name/nm0424060/'),
    ('Sofia Vergara', 'https://www.imdb.com/name/nm0005527/'),
    ('Chris Evans', 'https://www.imdb.com/name/nm0262635/')
]

# %%
actors_words = {}

for actor in actors:
    filename = '_'.join(actor[0].split(' '))
    with open(f'{filename}.json', 'r') as f:
        actors_words[filename] = json.load(f)

# %%
clouds = {}

for pair in actors_words.items():
    clouds[pair[0]] = WordCloud(
        stopwords={'find', 'the', 'a', 'to', 'in', 'and', 'of',
                   'with', 'from', 'as', 'their', 'for', 'an', 'his',
                  'are', 'on', 'when', 'by', 'that', 'i', 'he', 'her',
                  'they', 'is', 'into', 'at', 'but', 'has', 'while', 'before',
                  'him', 'them', 'film', 'new', 'who', 'after', 'man', 'up', 'it',
                  'will', 'must'}
    ).generate(' '.join(pair[1]))

# %%
plt.imshow(clouds['Dwayne_Johnson'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Chris_Hemsworth'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Robert_Downey_Jr.'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Akshay_Kumar'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Jackie_Chan'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Bradley_Cooper'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Adam_Sandler'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Scarlett_Johansson'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Sofia_Vergara'], interpolation='bilinear')
plt.axis("off");

# %%
plt.imshow(clouds['Chris_Evans'], interpolation='bilinear')
plt.axis("off");
